# %% [markdown]
# **Exceptions**
#
# **Exception Handling**

# %%
try:
    num1 = 7
    num2 = 0
    print (num1 / num2)
    print("Done calculation")
except ZeroDivisionError:
    print("An error occurred")
    print("due to zero division")
# Out:
# An error occurred
# due to zero division

# %%
try:
    variable = 10
    print(variable + "hello")
    print(variable / 2)
except ZeroDivisionError:
    print("Divided by zero")
except (ValueError, TypeError):
    print("Error occurred")
# Out:
# Error occurred

# %%
try:
    word = "spam"
    print(word / 0)
except:
    print("An error occurred")
# Out:
# An error occurred

# %% [markdown]
# **finally**

# %%
try:
    print("Hello")
    print(1 / 0)
except ZeroDivisionError:
    print("Divided by zero")
finally:
    print("This code will run no matter what")
# Out:
# Hello
# Divided by zero
# This code will run no matter what

# %% [markdown]
# **else**

# %%
try:
    print(1)
except ZeroDivisionError:
    print(2)
else:
    print(3)

try:
    print(1/0)
except ZeroDivisionError:
    print(4)
else:
    print(5)
# Out:
# 1
# 3
# 4

# %% [markdown]
# **Raising Exceptions**

# %%
num = 102
if num > 100:
  raise ValueError
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-91dfe72911ec> in <module>()
#       1 num = 102
#       2 if num > 100:
# ----> 3   raise ValueError
#
# ValueError:

# %%
name = "123"
raise NameError("Invalid name!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-d5ceb78ca603> in <module>()
#       1 name = "123"
# ----> 2 raise NameError("Invalid name!")
#
# NameError: Invalid name!
